# %% [markdown]
# # Lie Detection

# %%
# imports
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# necessary files
clips = pd.read_csv('data-files/transcript_data_combined.csv')
clips['Transcript'] = clips['Transcript'].fillna('')
lies = pd.read_csv('data-files/all_speech_lies.csv')
lies["Lie Quote"] = lies["Lie Quote"].fillna('')
print(lies.columns)
# Out:
# Index(['Speech ID', 'Lie Quote'], dtype='object')

# %%
vectorizer = CountVectorizer()

lie_vector = vectorizer.fit_transform(lies['Lie Quote'])
transcript_vector = vectorizer.transform(clips['Transcript'])

# %%
cosine_similarities = cosine_similarity(transcript_vector, lie_vector)

clips['Cosine_Similarity'] = cosine_similarities.max(axis=1)
max_similarity_indices = cosine_similarities.argmax(axis=1)
clips['Corresponding_Lie'] = lies['Lie Quote'].iloc[max_similarity_indices].values  # Get the corresponding lie

lies = clips[clips["Cosine_Similarity"] > 0.6]
truths = clips[clips["Cosine_Similarity"] <= 0.6]

lies = lies[["Chunk Filename", "Transcript", "Cosine_Similarity", "Corresponding_Lie"]]
print(len(lies))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Lie Quote'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 5
#       3 clips['Cosine_Similarity'] = cosine_similarities.max(axis=1)
#       4 max_similarity_indices = cosine_similarities.argmax(axis=1)
# ----> 5 clips['Corresponding_Lie'] = lies['Lie Quote'].iloc[max_similarity_indices].values  # Get the corresponding lie
#       7 lies = clips[clips["Cosine_Similarity"] > 0.6]
#       8 truths = clips[clips["Cosine_Similarity"] <= 0.6]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Lie Quote'

# %%
lies.to_csv("data-files/lies.csv")

# %%
lies
# Out:
#                                         Chunk Filename  \
# 37   /Users/milanvaghani/Desktop/Unstructed Machine...
# 39   /Users/milanvaghani/Desktop/Unstructed Machine...
# 41   /Users/milanvaghani/Desktop/Unstructed Machine...
# 45   /Users/milanvaghani/Desktop/Unstructed Machine...
# 47   /Users/milanvaghani/Desktop/Unstructed Machine...
# 52   /Users/milanvaghani/Desktop/Unstructed Machine...
# 56   /Users/milanvaghani/Desktop/Unstructed Machine...
# 57   /Users/milanvaghani/Desktop/Unstructed Machine...
# 88   /Users/milanvaghani/Desktop/Unstructed Machine...
# 158  /Users/milanvaghani/Desktop/Unstructed Machine...
# 189  /Users/milanvaghani/Desktop/Unstructed Machine...
# 286  /Users/milanvaghani/Desktop/Unstructed Machine...
# 301  /Users/milanvaghani/Desktop/Unstructed Machine...
# 328  /Users/milanvaghani/Desktop/Unstructed Machine...
# 489  /Users/milanvaghani/Desktop/Unstructed Machine...
# 522  /Users/milanvaghani/Desktop/Unstructed Machine...
#
#                                             Transcript  Cosine_Similarity  \
# 37   who assaulted those law enforcement officers a...           0.787499
# 39   to improve your life not to strengthen our nat...           0.761049
# 41   funny tried to get rid of the Affordable Care ...           0.700071
# 45   Aurora area small town or big city and as pres...           0.921106
# 47   his billionaire friends and he will give them ...           0.822581
# 52   because of Donald Trump  and understand he is ...           0.924014
# 56   and live free from the pollution that fuels th...           0.842750
# 57   and let me be clear and let me be clear after ...           0.769316
# 88   behind me and to the right was a large screen ...           0.864028
# 158  making most of our decisions actually it's all...           0.816754
# 189  everybody's a large large group of people that...           0.941369
# 286  has no intention to grow our middle class he's...           0.742153
# 301  inconsistent and transparent rules of the road...           0.720106
# 328  but as I said Civic leaders Community leaders ...           0.716350
# 489  just going all of the people in North Carolina...           0.789549
# 522  I will always protect Social Security and Medi...           0.718857
#
#                                      Corresponding_Lie
# 37   His explicit intent to jail journalists, polit...
# 39   we know and we know what a second Trump term w...
# 41   We are not going to let him end programs like ...
# 45   as president, I will bring together labor and ...
# 47   And all the while he intends to enact what, in...
# 52   This is what's happening in our country becaus...
# 56   With this election, we finally have the opport...
# 57   Last year, Joe and I brought together Democrat...
# 88   Behind me and to the right was a large screen ...
# 158  the best economy in the history of our country...
# 189  Democrats are going to destroy Social Security...
# 286  You can see it spelled out in his economic age...
# 301  as president, I will bring together labor and ...
# 328  the best economy in the history of our country...
# 489  They're offering them 750 dollars to people wh...
# 522  Democrats are going to destroy Social Security...
